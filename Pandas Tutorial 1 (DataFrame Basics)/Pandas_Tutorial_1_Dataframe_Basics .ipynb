# %%
import pandas as pd

# %%
df = pd.read_csv("weather_data.csv")
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
# You can also create your own Dataframe by using python dictionary
df = weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Rain', 'Sunny']
}

df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
# shape means the dimensions, 6 rows (0 is counted as well) and 4 columns
rows, columns = df.shape
rows
columns
# Out:
# 4

# %%
# It prints inital few rows (Useful for big dataset)
df.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %%
# You can specify the number of rows you want to print (0 is counted as a row)
df.head(2)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny

# %%
# It prints last 5 rows
df.tail()
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
# It prints last one row
df.tail(1)
# Out:
#         day  temperature  windspeed  event
# 5  1/6/2017           31          2  Sunny

# %%
# index slicing!
df[2:5]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Rain

# %%
# If you want to print everything (you can use either of them)
df[:]
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
# In order to print colums you use: (PRINTS THE NUMBER OF COLUMNS )
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
# If you want to print the individual columns (CONTENT OF COLUMNS)
df.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df.event
df["event"]
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# Name: event, dtype: object

# %%
# the columns in your dataset are basically of types and in Pandas they're sereis
type(df['event'])
# Out:
# pandas.core.series.Series

# %%
# It prints individual columns, if you want to
df[["event",'day']]
# Out:
#    event       day
# 0   Rain  1/1/2017
# 1  Sunny  1/2/2017
# 2   Snow  1/3/2017
# 3   Snow  1/4/2017
# 4   Rain  1/5/2017
# 5  Sunny  1/6/2017

# %%
# It prints the entire temperature column
df['temperature']
# Out:
# 0    32
# 1    35
# 2    28
# 3    24
# 4    32
# 5    31
# Name: temperature, dtype: int64

# %%
# # It prints the the maximum temperature
df['temperature'].max()
# Out:
# 35

# %%
# # It prints the the average of temperatures
df['temperature'].mean()
# Out:
# 30.333333333333332

# %%
# # It prints the minnimum temperature
df['temperature'].min()
# Out:
# 24

# %%
# # It prints the standard deviation
df['temperature'].std()
# Out:
# 3.8297084310253524

# %%
# It prints the statistics on your dataset
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
# Conditionally selecting data 
df[df.temperature>=32]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 4  1/5/2017           32          4   Rain

# %%
df[df.temperature==df['temperature'].max()]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
# It prints only the day instead of other columns where temperature was maximum
df['day'][df.temperature==df['temperature'].max()]
# Out:
# 1    1/2/2017
# Name: day, dtype: object

# %%
df[['day', 'temperature']][df.temperature==df['temperature'].max()]
# Out:
#         day  temperature
# 1  1/2/2017           35

# %%
# Pandas has whole bunch of opreations on their documentation
# https://pandas.pydata.org/docs/reference/api/pandas.Series.html

# %%
# If you look closely , it contaions integer index which it assigns it automatically ( 6 IS NOT INCLUDED)
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
# Let's say if you wanna change the index to be something else like "DAY"
df.set_index('day', inplace=True)
# Now the index is changed to actual day
# The advantage of this is now you can run the loc funtion and say that give me the data on the specific date

# %%
df.loc['1/4/2017']
# It gives you an error because when you run set_index command, it gives you a new dataset instead of modifying the original
# to modify the original one you have to say df.set_index('day', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-78537c0ed2cc> in <module>
# ----> 1 df.loc['1/4/2017']
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
# ...

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df.loc['1/3/2017']
# Out:
# temperature      28
# windspeed         2
# event          Snow
# Name: 1/3/2017, dtype: object

# %%
# if you want to reset the index, you can do this:  (IT REQUIRES YOU TO PUT INPLACE=TRUE)
df.reset_index(inplace=True)
df
# Out:
#    event  index       day  temperature  windspeed
# 0   Rain      0  1/1/2017           32          6
# 1  Sunny      1  1/2/2017           35          7
# 2   Snow      2  1/3/2017           28          2
# 3   Snow      3  1/4/2017           24          7
# 4   Rain      4  1/5/2017           32          4
# 5  Sunny      5  1/6/2017           31          2

# %%
df.set_index('event', inplace=True)
df
# You can see that index is not unique, because events get repeated
# Out:
#        index       day  temperature  windspeed
# event
# Rain       0  1/1/2017           32          6
# Sunny      1  1/2/2017           35          7
# Snow       2  1/3/2017           28          2
# Snow       3  1/4/2017           24          7
# Rain       4  1/5/2017           32          4
# Sunny      5  1/6/2017           31          2

# %%
# You can get values associated with Snow like a hash function as a particular column like hash key.
df.loc['Snow']
# Out:
#        index       day  temperature  windspeed
# event
# Snow       2  1/3/2017           28          2
# Snow       3  1/4/2017           24          7
